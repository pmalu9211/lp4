# %%
import tensorflow
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)

x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
loss = SGD(learning_rate=0.01)

model.compile(optimizer=loss, metrics=["accuracy"], loss="sparse_categorical_crossentropy")

# %%
history = model.fit(x_train, y_train, epochs=11, validation_data=(x_test, y_test)) #epochs = the number of time we are going throught the dataset again
# Out:
# Epoch 1/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9299 - loss: 0.2440 - val_accuracy: 0.9350 - val_loss: 0.2225
# Epoch 2/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9393 - loss: 0.2100 - val_accuracy: 0.9431 - val_loss: 0.1944
# Epoch 3/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9468 - loss: 0.1851 - val_accuracy: 0.9477 - val_loss: 0.1714
# Epoch 4/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9520 - loss: 0.1659 - val_accuracy: 0.9506 - val_loss: 0.1642
# Epoch 5/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9569 - loss: 0.1507 - val_accuracy: 0.9585 - val_loss: 0.1426
# Epoch 6/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9601 - loss: 0.1372 - val_accuracy: 0.9597 - val_loss: 0.1338
# Epoch 7/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9641 - loss: 0.1258 - val_accuracy: 0.9638 - val_loss: 0.1254
# Epoch 8/11
# ...

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9697 - loss: 0.1047
# Test Loss: 0.10474696010351181
# Test Accuracy: 0.9696999788284302

# %%
a = model.predict(x_test)
plt.imshow(x_test[1])
plt.show()
print(np.argmax(a[1], axis=0))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 2

# %%
# history.history
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title("Training vs Testing Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Train acc')
plt.plot(history.history['val_accuracy'], label='Test acc')
plt.title("Training vs Testing acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()
