# %%
import tensorflow

# %%
from tensorflow.keras.applications import VGG16

base = VGG16(
    weights="/Users/prathamesh/Downloads/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5",
    include_top=False,
    input_shape=(224,224,3)
)

for layer in base.layers:
    layer.trainable = False

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

imgen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2
)

# %%
imgen.flow_from_directory?
# Out:
# Signature:
# imgen.flow_from_directory(
#     directory,
#     target_size=(256, 256),
#     color_mode='rgb',
#     classes=None,
#     class_mode='categorical',
#     batch_size=32,
#     shuffle=True,
#     seed=None,
#     save_to_dir=None,
#     save_prefix='',
#     save_format='png',
#     follow_links=False,
#     subset=None,
#     interpolation='nearest',
#     keep_aspect_ratio=False,
# )
# Docstring: <no docstring>
# File:      ~/Desktop/pratham/venv/lib/python3.10/site-packages/keras/src/legacy/preprocessing/image.py
# Type:      method

# %%
selectedSlasses = ["airplanes", "ant"]
train_data = imgen.flow_from_directory(
    "/Users/prathamesh/Downloads/images/",
    target_size=(224,224),
    classes = subclasses,
    subset="training"
)

val_data = imgen.flow_from_directory(
    "/Users/prathamesh/Downloads/images/",
    target_size=(224,224),
    classes = subclasses,
    subset="validation"
)
# Out:
# Found 674 images belonging to 2 classes.
# Found 168 images belonging to 2 classes.

# %%
train_data.num_classes
# Out:
# 2

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
model = Sequential([
    base,
    Flatten(),
    Dense(256, activation="relu"),
    Dropout(0.2),
    Dense(256, activation="relu"),
    Dropout(0.4),
    Dense(train_data.num_classes, activation="softmax")
])

model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=Adam())

model.fit(train_data, validation_data=val_data, epochs=5 )
# Out:
# Epoch 1/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.9080 - loss: 0.4901 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 2/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 77s 4s/step - accuracy: 0.9955 - loss: 0.0251 - val_accuracy: 1.0000 - val_loss: 7.8229e-06
# Epoch 3/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 79s 4s/step - accuracy: 0.9955 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 1.2467e-06
# Epoch 4/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9926 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 5/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.9985 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 1.5276e-06

# %%
mode.
